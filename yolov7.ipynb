# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197
# Receiving objects: 100% (1197/1197), 74.23 MiB | 26.03 MiB/s, done.
# Resolving deltas: 100% (519/519), done.

# %%
# %cd yolov7
# Out:
# /content/yolov7

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 67.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/yolov7/Final_dataset.v2i.yolov8.zip
# Out:
# Archive:  /content/drive/MyDrive/yolov7/Final_dataset.v2i.yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/ZJ000427_jpg.rf.3013e14d4c71ed8bc74b60c4050369b5.jpg
#  extracting: test/images/ZJ002151_jpg.rf.5c480bf7b3c0683cb223d5d85f126c48.jpg
#  extracting: test/images/ZJ002188_jpg.rf.d30dbf7b1c9eae314ac900839b9fd029.jpg
#  extracting: test/images/ZJ002342_jpg.rf.3f616b773b38be7173537195cd66e5d7.jpg
#  extracting: test/images/ZJ002466_jpg.rf.54abbba4f958dfd862ae3cd4dde79363.jpg
#  extracting: test/images/ZJ002549_jpg.rf.3fdf87b188fafbfdb6e61fdc77791dd0.jpg
#  extracting: test/images/ZJ002636_jpg.rf.bc3c7d75c606da74c1e5b9257ad56e80.jpg
#  extracting: test/images/ZJ002754_jpg.rf.ad0c957345510149e5599a5b58358da3.jpg
#  extracting: test/images/ZJ003080_jpg.rf.36b917c42e96d862af0f11d80cf83c16.jpg
# ...

# %%
import os

# %%
train_img_path="/content/yolov7/train/images"
val_img_path="/content/yolov7/valid/images"
test_img_path="/content/yolov7/test/images"

# %%
# %cd /content
# Out:
# /content

# %%
#training img
with open('train.txt',"a+") as f:
  img_list=os.listdir(train_img_path)
  for img in img_list:
    f.write(os.path.join(train_img_path,img+'\n'))
print('Done')
# Out:
# Done

# %%
#val img
with open('val.txt',"a+") as f:
  img_list=os.listdir(val_img_path)
  for img in img_list:
    f.write(os.path.join(val_img_path,img+'\n'))
print('Done')
# Out:
# Done

# %%
#test img
with open('test.txt',"a+") as f:
  img_list=os.listdir(test_img_path)
  for img in img_list:
    f.write(os.path.join(test_img_path,img+'\n'))
print('Done')
# Out:
# Done

# %%
# %cp /content/yolov7/data/coco.yaml /content/yolov7/data/custom.yaml

# %%
# %cd /content/yolov7/
#!wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"
# Out:
# /content/yolov7

# %%
# %cp /content/yolov7/cfg/training/yolov7.yaml /content/yolov7/cfg/training/custom_yolov7.yaml

# %%
# !python train.py --batch 16  --cfg /content/yolov7/cfg/training/custom_yolov7.yaml --epochs 50 --data /content/yolov7/data/custom.yaml --weights '/content/drive/MyDrive/yolov7/Runs/Run_20May252/weights/last.pt' --project "/content/drive/MyDrive/yolov7/Runs" --name Run_09Jun --device 0
# Out:
# 2024-06-09 08:47:51.483000: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 08:47:51.483067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 08:47:51.484992: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-09 08:47:51.496494: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py  --weights /content/drive/MyDrive/yolov7/Runs/Run_20May252/weights/last.pt --source /content/ZJ000040.jpg
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/Runs/Run_20May252/weights/last.pt'], source='/content/ZJ000040.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.1+cu121 CUDA:0 (Tesla T4, 15102.0625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36514136 parameters, 6194944 gradients, 103.3 GFLOPS
# ...

# %%
# !python test.py --data /content/drive/MyDrive/yolov7/ValidDataset.v2i.yolov8-obb_yolov7/data.yaml --conf 0.1 --device 0 --weights /content/drive/MyDrive/yolov7/Runs/Run_20May252/weights/last.pt
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/Runs/Run_20May252/weights/last.pt'], data='/content/drive/MyDrive/yolov7/ValidDataset.v2i.yolov8-obb_yolov7/data.yaml', batch_size=32, img_size=640, conf_thres=0.1, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='exp', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.3.0+cu121 CUDA:0 (Tesla T4, 15102.0625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
/content/valid/images
