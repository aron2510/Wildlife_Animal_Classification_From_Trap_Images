# %%
# !nvidia-smi
# Out:
# Tue Feb 20 13:54:53 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.4/715.4 kB 15.2 MB/s eta 0:00:00
# ...

# %%
cd /content/drive/MyDrive/YoloV8
# Out:
# /content/drive/MyDrive/YoloV8

# %%
ls
# Out:
# animal_classification.v2i.yolov8.zip  README.dataset.txt   test/   YoloV8.ipynb    yolov8s.pt
# data.yaml                             README.roboflow.txt  train/  yolov8n.pt
# Final/                                runs/                valid/  yolov8n-seg.pt

# %%
# !unzip /content/drive/MyDrive/YoloV8/Final/Final_dataset_200.v1i.yolov8-obb.zip
# Out:
# Archive:  /content/drive/MyDrive/YoloV8/Final/Final_dataset_200.v1i.yolov8-obb.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#  extracting: README.dataset.txt
# replace README.roboflow.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#  extracting: README.roboflow.txt
# replace data.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#  extracting: data.yaml
#  extracting: test/images/ZJ000211_jpg.rf.a952eb8f6a87edcaf79b03528faa7e39.jpg
#  extracting: test/images/ZJ000247_jpg.rf.cf0e70798397e9af029427266d4b9620.jpg
#  extracting: test/images/ZJ000263_jpg.rf.9a9cc624d99618fd0adbfd1f20fbdad3.jpg
#  extracting: test/images/ZJ000382_jpg.rf.d235fcf5947dad42f80785f694ac7297.jpg
#  extracting: test/images/ZJ000392_jpg.rf.f7f38b6b2722b66d2b592bd1e4220d46.jpg
#  extracting: test/images/ZJ000428_jpg.rf.1fdb79a331006e3066a437c99781ad46.jpg
#  extracting: test/images/ZJ000435_jpg.rf.7741f14a25e4eef90da96a8eb21684fb.jpg
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n-seg.pt")

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=100 imgsz=640 plots=True
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train7/
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1708438079.8d47a472d678.6078.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	 val_batch2_pred.jpg
# labels.jpg					    train_batch7470.jpg  weights
# P_curve.png					    train_batch7471.jpg
# PR_curve.png					    train_batch7472.jpg

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YoloV8/runs/detect/train7/weights/best.pt conf=0.25 source=/content/ZJ000304.jpg
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/ZJ000304.jpg: 384x640 1 rodent, 105.1ms
# Speed: 3.6ms preprocess, 105.1ms inference, 619.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict50
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/YoloV8/runs/detect/train7/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.1.16 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/drive/MyDrive/YoloV8/valid/labels.cache... 98 images, 0 backgrounds, 0 corrupt: 100% 98/98 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 68, len(boxes) = 98. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:04<00:00,  1.52it/s]
#                    all         98         98      0.714      0.535      0.587      0.302
#               Antelope         98         98      0.714      0.535      0.587      0.302
# Speed: 4.9ms preprocess, 12.8ms inference, 0.0ms loss, 11.0ms postprocess per image
# ...

# %%
# !yolo export model=yolov8n.pt format=torchscript

# %%
onnx,tflite,torchscript
